# %%
import flor

# %%
pubmed_metadata = flor.dataframe("title", "journal", "authors", "cited_pmids")
pubmed_metadata
# Out:
#    pmid pmid_value  article                  projid              tstamp  \
# 0     7   15477533        1  research_reviewer_main 2024-09-30 10:22:29
# 1     6   17898010        1  research_reviewer_main 2024-09-30 10:22:29
# 2    13   20802215        1  research_reviewer_main 2024-09-30 10:22:29
# 3    15   21525425        1  research_reviewer_main 2024-09-30 10:22:29
# 4     9   33313379        1  research_reviewer_main 2024-09-30 10:22:29
# 5     1   33609479        1  research_reviewer_main 2024-09-30 10:22:29
# 6    12   34992100        1  research_reviewer_main 2024-09-30 10:22:29
# 7     2   35913095        1  research_reviewer_main 2024-09-30 10:22:29
#
#                 filename                                              title  \
# 0  fetch_IDs_metadata.py  Clinical, genetic, and neuropathologic charact...
# 1  fetch_IDs_metadata.py  Focal cortical presentations of Alzheimer's di...
# 2  fetch_IDs_metadata.py  Cerebrospinal fluid biomarkers in the differen...
# ...

# %%
page_text = flor.dataframe("page_text")
page_text = page_text[["projid", "tstamp", "filename", "paper", "paper_value", "page", "page_text"]]
page_text

# %%
synthetic_papers = flor.utils.latest(flor.dataframe("title", "author", "references"))
synthetic_papers = synthetic_papers[["projid", "tstamp", "filename", "paper", "title", "author", "references"]]
synthetic_papers
