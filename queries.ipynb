# %%
import flor

# %%
pubmed_metadata = flor.dataframe("title", "journal", "authors", "cited_pmids")
pubmed_metadata
# Out:
#    pmid pmid_value                  projid              tstamp  \
# 0     1   39309254  research_reviewer_main 2024-09-30 10:47:49
# 1     3   39309578  research_reviewer_main 2024-09-30 10:47:49
# 2     5   39310682  research_reviewer_main 2024-09-30 10:47:49
# 3     2   39323593  research_reviewer_main 2024-09-30 10:47:49
# 4     4   39329067  research_reviewer_main 2024-09-30 10:47:49
#
#                 filename                                              title  \
# 0  fetch_IDs_metadata.py  Imagining machine vision: Four visual register...
# 1  fetch_IDs_metadata.py  532 nm versus 810 nm subthreshold micropulse l...
# 2  fetch_IDs_metadata.py  VALIDATION OF THE QUALITY OF RECOVERY-40 QUEST...
# 3  fetch_IDs_metadata.py  The carbon footprint of Bubble-PAPR™: A novel ...
# 4  fetch_IDs_metadata.py  Consensus recommendations for clinical assessm...
#
#                                            journal  \
# 0                                     AI & society
# ...
