# %%
import flor

# %%
flor.dataframe("page_text")
# Out:
#     pdf             pdf_value  page                  projid  \
# 0     1  known_pdfs/p4045.pdf     1  research_reviewer_main
# 1     1  known_pdfs/p4045.pdf     2  research_reviewer_main
# 2     1  known_pdfs/p4045.pdf     3  research_reviewer_main
# 3     1  known_pdfs/p4045.pdf     4  research_reviewer_main
# 4     1  known_pdfs/p4045.pdf     5  research_reviewer_main
# 5     1  known_pdfs/p4045.pdf     6  research_reviewer_main
# 6     1  known_pdfs/p4045.pdf     7  research_reviewer_main
# 7     1  known_pdfs/p4045.pdf     8  research_reviewer_main
# 8     1  known_pdfs/p4045.pdf     9  research_reviewer_main
# 9     1  known_pdfs/p4045.pdf    10  research_reviewer_main
# 10    1  known_pdfs/p4045.pdf    11  research_reviewer_main
# 11    1  known_pdfs/p4045.pdf    12  research_reviewer_main
#
#                 tstamp       filename  \
# 0  2024-08-20 09:53:22  parse_text.py
# 1  2024-08-20 09:53:22  parse_text.py
# 2  2024-08-20 09:53:22  parse_text.py
# ...
